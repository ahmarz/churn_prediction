# %% [markdown]
# # Imports

# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns


from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_curve, auc
from sklearn import model_selection
from sklearn.model_selection import StratifiedKFold

from keras.utils import np_utils
from keras.models import Sequential
from keras.layers.core import Dense, Activation, Dropout

# %%
# !ls
# Out:
# .DS_Store
# .ipynb_checkpoints
# Data Scientist Final Evaluation v2021 (1).pdf
# Untitled.ipynb
# dataset
# dataset (1).zip

# %% [markdown]
# # Lets Look at Data

# %%
df_app_start = pd.read_csv('dataset/app starts.txt', sep='\t')

# %%
df_app_start
# Out:
#                         dateCreated                                userId
# 0       2017-06-30 14:14:54.7930000  50e72534-a4f4-40d7-96d5-ecbe4eb314e9
# 1       2017-06-30 14:03:13.0100000  b3712849-595e-403f-84d2-4698439056b0
# 2       2017-06-28 16:26:48.3830000  99cea50b-3ecf-4102-8290-997eaf32a6b6
# 3       2017-06-27 10:23:29.9430000  78c06433-9ea8-4835-aff5-f64b262d0fb4
# 4       2017-06-27 10:11:27.6340000  510c5f9e-de54-45ee-909c-c14103130e5e
# ...                             ...                                   ...
# 144099  2017-04-06 07:44:14.5000000  a5b61f0a-4c5e-4e22-8c81-f201b35ced0a
# 144100  2017-04-04 21:41:27.0000000  221996a6-4560-4e5e-b2d4-ca5c2837ca46
# 144101  2017-04-04 20:24:49.0000000  a177cd12-da14-4b3e-ab19-19e150fad99f
# 144102  2017-04-04 20:05:05.0000000  087EFEA9-5100-4101-9A47-835AC833203F
# 144103  2017-04-03 09:23:40.0000000  c58db4eb-2431-46b6-80b4-e34d30f0b543
#
# [144104 rows x 2 columns]

# %%
df_app_start.value_counts()
# Out:
# dateCreated                  userId
# 2017-04-02 19:04:02.0000000  7f769117-539e-4c79-b319-eb0d8df1a48b    3
# 2017-04-08 00:26:13.5310000  680e5042-9123-4754-9ccd-229107f76d98    2
# 2017-04-08 00:40:36.9100000  4497c689-8bf7-43fd-9a74-cb8b506a31c6    2
# 2017-04-08 00:38:15.9760000  9023416c-03de-44b9-b468-d142e9be353c    2
# 2017-04-08 00:38:03.7290000  6e27873b-4ef6-4ca3-be6d-45aee0f86def    2
#                                                                     ..
# 2017-05-10 05:51:22.8570000  ad6412ca-c607-49a2-9565-8b1a1df5409e    1
# 2017-05-10 05:51:19.9650000  73e4dc61-2bb3-4349-9861-f204c6dc9ae9    1
# 2017-05-10 05:49:40.1280000  8853e318-cea4-4603-9bf1-f6fdee65e9ec    1
# 2017-05-10 05:44:04.8160000  9db71749-8511-4a89-942d-1d9f6e4bea10    1
# 2017-06-30 23:59:34.4070000  62c23f15-6e44-4f58-a514-6433a7541898    1
# Length: 144052, dtype: int64

# %%
df_appStart_july = pd.read_csv('dataset/app starts july.txt', sep='\t')

# %%
df_appStart_july
# Out:
#                        dateCreated                                userId
# 0      2017-07-31 21:24:51.4230000  c6adac02-336f-4cfb-9478-f7b822200215
# 1      2017-07-31 21:10:24.9810000  4b498ee2-2207-45d6-805e-929491a0bb6a
# 2      2017-07-31 20:58:27.6010000  e49dd902-816e-4e32-8320-9580340eaa1d
# 3      2017-07-31 20:41:32.7670000  b28aaf42-476f-489d-8b90-f430a3788c5a
# 4      2017-07-29 16:51:55.2170000  4bfb581c-a205-4189-bac1-c579fb92c575
# ...                            ...                                   ...
# 39964  2017-07-01 19:13:01.9380000  7408ba54-9c3d-4931-945c-10458c9971d0
# 39965  2017-07-01 18:55:39.6830000  c5e62f1e-3739-48e3-bfcf-373bc8cfcec9
# 39966  2017-07-01 18:49:29.2550000  758dbaba-67fe-4173-908a-cf16045eed88
# 39967  2017-07-01 18:44:18.6520000  6db90257-0d7a-4a01-9171-4a55e76d7c03
# 39968  2017-07-01 18:26:14.3080000  d6d77a96-5869-4899-b665-56f75697a29e
#
# [39969 rows x 2 columns]

# %%
df_appStart_july.value_counts()
# Out:
# dateCreated                  userId
# 2017-07-01 00:00:17.3830000  a847ffb7-3330-49e0-b6cc-f05880b628c6    1
# 2017-07-20 16:59:32.5920000  0168c17b-4ee0-41c1-9f9e-4b43601f2bbc    1
# 2017-07-20 16:57:21.1650000  24b6bba1-2e12-44a2-b7a9-10e399c21428    1
# 2017-07-20 16:57:39.4720000  3d155e81-4d6f-4a3e-a4e4-42c0be7530bc    1
# 2017-07-20 16:58:11.9260000  be2e8d5b-b421-4809-b6f1-da5a262252e4    1
#                                                                     ..
# 2017-07-09 21:12:00.5960000  594ef349-2541-4ef2-868c-e847342b3ace    1
# 2017-07-09 21:12:07.9090000  c94ecc0a-154f-4a53-b00b-eabaf2ea2ba8    1
# 2017-07-09 21:12:22.7810000  ec79aea5-f952-4505-ab2e-603864bde557    1
# 2017-07-09 21:12:32.3250000  940b6097-397c-49cd-8dbf-16cb2edf0ffa    1
# 2017-07-31 23:59:31.5100000  5888c2f9-d01e-49f1-80d3-b38900b157d4    1
# Length: 39969, dtype: int64

# %%
# df_appStart_july.loc[df_appStart_july['userId'] == 'a847ffb7-3330-49e0-b6cc-f05880b628c6']

# %%
df_installs = pd.read_csv('dataset/installs.txt', sep='\t')

# %%
df_installs
# Out:
#              id                  InstallDate          productId  \
# 0      37371890  2017-05-04 10:06:27.8070000   de.kaufda.kaufda
# 1      36979918  2017-04-24 09:27:16.1730000  com-bonial-kaufda
# 2      37371070  2017-05-04 16:05:09.5680000   de.kaufda.kaufda
# 3      36897929  2017-04-22 13:18:18.4370000  com-bonial-kaufda
# 4      36606053  2017-04-15 14:03:51.1990000  com-bonial-kaufda
# ...         ...                          ...                ...
# 19995  36522756  2017-04-12 00:23:05.8670000   de.kaufda.kaufda
# 19996  37992605  2017-05-18 09:00:48.4390000  de-kaufda-android
# 19997  37725883  2017-05-11 21:55:39.2290000   de.kaufda.kaufda
# 19998  37145842  2017-04-27 22:37:18.7530000   de.kaufda.kaufda
# 19999  37499616  2017-05-08 19:18:18.9280000  com-bonial-kaufda
#
#                                      userId           model campaignId
# 0      5fc13850-de51-4426-96ce-72aaec895abb         ipad2,7     000000
# ...

# %%
df_brochViews = pd.read_csv('dataset/brochure views.txt', sep='\t')

# %%
df_brochViews
# Out:
#                 id                                userId  \
# 0       6269194661  9491a960-206a-4a58-9177-e78cb1f05e70
# 1       6269192581  9491a960-206a-4a58-9177-e78cb1f05e70
# 2       6269188351  9491a960-206a-4a58-9177-e78cb1f05e70
# 3       6204426632  fa623647-dfc9-49b4-bbb6-77cbacd599f4
# 4       6204424112  9491a960-206a-4a58-9177-e78cb1f05e70
# ...            ...                                   ...
# 279208  6689610182  2d19229c-8e8f-4651-90aa-8e7cc937625d
# 279209  6689147082  d9b12c6f-3cb0-4dec-9866-76c4cf65a878
# 279210  6751261341  d9b12c6f-3cb0-4dec-9866-76c4cf65a878
# 279211  6750596911  37b49f54-cb1a-4c48-a716-0eab645798ff
# 279212  6688485372  37b49f54-cb1a-4c48-a716-0eab645798ff
#
#                         dateCreated  page_turn_count  view_duration  \
# 0       2017-04-30 23:47:09.5390000               30        95172.0
# 1       2017-04-30 23:47:00.6970000                2         4000.0
# 2       2017-04-30 23:46:39.9170000                1        14000.0
# ...

# %%
df_brochViews_july = pd.read_csv('dataset/brochure views july.txt', sep='\t')

# %%
df_brochViews_july
# Out:
#                 id                                userId  \
# 0      10670800401  a1bf423c-35d2-4509-8ad2-ec262e46bdb8
# 1      12024284821  C9DAFB1D-5D4C-40C4-B3F7-9C542594D128
# 2      12026473907  C9DAFB1D-5D4C-40C4-B3F7-9C542594D128
# 3      12026471343  C9DAFB1D-5D4C-40C4-B3F7-9C542594D128
# 4      12026471276  C9DAFB1D-5D4C-40C4-B3F7-9C542594D128
# ...            ...                                   ...
# 74426   7242007291  d3407ab9-8051-4b04-bc29-17e506b7061a
# 74427   7241953361  edced8a6-ee66-4d5a-98bf-176fb30033d9
# 74428   7241953331  edced8a6-ee66-4d5a-98bf-176fb30033d9
# 74429   7241947901  edced8a6-ee66-4d5a-98bf-176fb30033d9
# 74430   7156188602  5ac0478d-23ec-4332-82f7-04da8277e13a
#
#                        dateCreated  page_turn_count  view_duration  \
# 0      2017-07-30 23:55:20.4010000               44       182139.0
# 1      2017-07-29 12:34:07.0660000                2         3000.0
# 2      2017-07-29 12:33:21.5520000               26        41000.0
# ...

# %%
df_brochViews_july.userId.isin(df_brochViews.userId).astype(int)
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 74426    1
# 74427    1
# 74428    1
# 74429    1
# 74430    1
# Name: userId, Length: 74431, dtype: int64

# %%
df_brochViews_july.assign(InDf_brochViews= df_brochViews_july.userId.isin(df_brochViews.userId).astype(int))
# Out:
#                 id                                userId  \
# 0      10670800401  a1bf423c-35d2-4509-8ad2-ec262e46bdb8
# 1      12024284821  C9DAFB1D-5D4C-40C4-B3F7-9C542594D128
# 2      12026473907  C9DAFB1D-5D4C-40C4-B3F7-9C542594D128
# 3      12026471343  C9DAFB1D-5D4C-40C4-B3F7-9C542594D128
# 4      12026471276  C9DAFB1D-5D4C-40C4-B3F7-9C542594D128
# ...            ...                                   ...
# 74426   7242007291  d3407ab9-8051-4b04-bc29-17e506b7061a
# 74427   7241953361  edced8a6-ee66-4d5a-98bf-176fb30033d9
# 74428   7241953331  edced8a6-ee66-4d5a-98bf-176fb30033d9
# 74429   7241947901  edced8a6-ee66-4d5a-98bf-176fb30033d9
# 74430   7156188602  5ac0478d-23ec-4332-82f7-04da8277e13a
#
#                        dateCreated  page_turn_count  view_duration  \
# 0      2017-07-30 23:55:20.4010000               44       182139.0
# 1      2017-07-29 12:34:07.0660000                2         3000.0
# 2      2017-07-29 12:33:21.5520000               26        41000.0
# ...

# %%
#Df1.assign(InDf2=Df1.name.isin(Df2.IDs).astype(int))

df_brochViews_july.assign(InDf_brochViews= df_brochViews_july.userId.isin(df_brochViews.userId).astype(int))['InDf_brochViews'].value_counts()
# Out:
# 1    73721
# 0      710
# Name: InDf_brochViews, dtype: int64

# %%
import pandas_profiling
pandas_profiling.ProfileReport(df_brochViews)
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.1.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2022-04-14 10:40:37.191171&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
df_corr = df_brochViews.corr()

df_corr[(df_corr > 0.2) & (df_corr < 1.0)].stack()
# Out:
# id               brochure_id        0.494954
# page_turn_count  view_duration      0.448355
# view_duration    page_turn_count    0.448355
# brochure_id      id                 0.494954
# dtype: float64

# %% [markdown]
# As we can see, view_duration is highly correlated with page_turn_count...basically the more interactions with the app the more the duration time..here assuming that view_duration is in milliseconds

# %%
df_brochViews.groupby(['page_turn_count']).apply(display)
# Out:
#                 id                                userId  \
# 2       6269188351  9491a960-206a-4a58-9177-e78cb1f05e70
# 4       6204424112  9491a960-206a-4a58-9177-e78cb1f05e70
# 6       6204465472  fa623647-dfc9-49b4-bbb6-77cbacd599f4
# 27      6268710581  33D2FC77-9518-41B7-96D4-17BE8D100534
# 31      6269342491  8094786a-b07c-47e9-8fed-237edf3e0c39
# ...            ...                                   ...
# 279168  6692730432  51449ee3-8782-4b93-9d41-aef38fd5a55c
# 279175  6698951282  556a6e5b-67a0-4f8d-bf76-6d2ff086a4ea
# 279184  6753202401  ddb065f8-79fc-41df-917d-da70f6db61f8
# 279187  6751420631  5f6a83f1-0404-472f-8dd8-0e9dcd8cf9f6
# 279192  6751354421  5f6a83f1-0404-472f-8dd8-0e9dcd8cf9f6
#
#                         dateCreated  page_turn_count  view_duration  \
# 2       2017-04-30 23:46:39.9170000                1        14000.0
# 4       2017-04-30 23:46:02.1970000                1        33000.0
# 6       2017-04-30 23:48:58.2380000                1         3000.0
# ...

# %%
df_brochViews['page_turn_count'].value_counts()
# Out:
# 1      70197
# 2      17662
# 3      12749
# 4       9698
# 8       8582
#        ...
# 245        1
# 188        1
# 291        1
# 305        1
# 196        1
# Name: page_turn_count, Length: 213, dtype: int64

# %% [markdown]
# # Create Labels

# %%
# df_brochViews['Churn'] = np.where(df_brochViews['page_turn_count']> 10, True, False)

df_brochViews['Churn'] = np.where(df_brochViews['page_turn_count']> 10, 0, 1)

# %%
df_brochViews
# Out:
#                 id                                userId  \
# 0       6269194661  9491a960-206a-4a58-9177-e78cb1f05e70
# 1       6269192581  9491a960-206a-4a58-9177-e78cb1f05e70
# 2       6269188351  9491a960-206a-4a58-9177-e78cb1f05e70
# 3       6204426632  fa623647-dfc9-49b4-bbb6-77cbacd599f4
# 4       6204424112  9491a960-206a-4a58-9177-e78cb1f05e70
# ...            ...                                   ...
# 279208  6689610182  2d19229c-8e8f-4651-90aa-8e7cc937625d
# 279209  6689147082  d9b12c6f-3cb0-4dec-9866-76c4cf65a878
# 279210  6751261341  d9b12c6f-3cb0-4dec-9866-76c4cf65a878
# 279211  6750596911  37b49f54-cb1a-4c48-a716-0eab645798ff
# 279212  6688485372  37b49f54-cb1a-4c48-a716-0eab645798ff
#
#                         dateCreated  page_turn_count  view_duration  \
# 0       2017-04-30 23:47:09.5390000               30        95172.0
# 1       2017-04-30 23:47:00.6970000                2         4000.0
# 2       2017-04-30 23:46:39.9170000                1        14000.0
# ...

# %%
#df_tmp.groupby(['customer_id', 'week']).apply(display)

# %% [markdown]
# # Further EDA

# %%
# df_corr = df_brochViews.corr()
# %matplotlib inline
plt.figure(figsize=(13,8))

mask = np.triu(np.ones_like(df_corr.corr(), dtype=bool))
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(df_corr.corr(), mask=mask, cmap=cmap, annot=True)

plt.show()

# %% [markdown]
# # Merge

# %%
df = pd.merge(df_installs, df_brochViews, on=['userId'], how='inner')

# %%
df
# Out:
#             id_x                  InstallDate          productId  \
# 0       36897929  2017-04-22 13:18:18.4370000  com-bonial-kaufda
# 1       36897929  2017-04-22 13:18:18.4370000  com-bonial-kaufda
# 2       36897929  2017-04-22 13:18:18.4370000  com-bonial-kaufda
# 3       36897929  2017-04-22 13:18:18.4370000  com-bonial-kaufda
# 4       36897929  2017-04-22 13:18:18.4370000  com-bonial-kaufda
# ...          ...                          ...                ...
# 208343  37499616  2017-05-08 19:18:18.9280000  com-bonial-kaufda
# 208344  37499616  2017-05-08 19:18:18.9280000  com-bonial-kaufda
# 208345  37499616  2017-05-08 19:18:18.9280000  com-bonial-kaufda
# 208346  37499616  2017-05-08 19:18:18.9280000  com-bonial-kaufda
# 208347  37499616  2017-05-08 19:18:18.9280000  com-bonial-kaufda
#
#                                       userId           model campaignId  \
# 0       64707e97-d5e1-4622-a89a-bebf8432fd33        sm-g955f     000000
# ...

# %%
df.productId.value_counts()
# Out:
# com-bonial-kaufda    179642
# de-kaufda-android     20613
# de.kaufda.kaufda       8093
# Name: productId, dtype: int64

# %%
# %matplotlib inline
plt.figure(figsize=(13,8))

mask = np.triu(np.ones_like(df.corr(), dtype=bool))
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(df.corr(), mask=mask, cmap=cmap, annot=True)

plt.show()

# %% [markdown]
# # Subselect Cols

# %%
X = df[['model', 'campaignId', 'page_turn_count', 'view_duration', 'productId']]

# %%
X
# Out:
#                  model campaignId  page_turn_count  view_duration  \
# 0             sm-g955f     000000               18        36000.0
# 1             sm-g955f     000000               40       161000.0
# 2             sm-g955f     000000               25        53000.0
# 3             sm-g955f     000000               25        27000.0
# 4             sm-g955f     000000                8       140000.0
# ...                ...        ...              ...            ...
# 208343  huawei+gra-l09     000000               43        90000.0
# 208344  huawei+gra-l09     000000                2        22000.0
# 208345  huawei+gra-l09     000000                1         8000.0
# 208346  huawei+gra-l09     000000                1        10000.0
# 208347  huawei+gra-l09     000000                3        40000.0
#
#                 productId
# 0       com-bonial-kaufda
# 1       com-bonial-kaufda
# 2       com-bonial-kaufda
# 3       com-bonial-kaufda
# 4       com-bonial-kaufda
# ...

# %% [markdown]
# # Training Data

# %%
X['model_encoded'] = LabelEncoder().fit_transform(X['model'])
X['campaignId_encoded'] = LabelEncoder().fit_transform(X['campaignId'])
X['page_turn_count_encoded'] = LabelEncoder().fit_transform(X['page_turn_count'])
X['view_duration_encoded'] = LabelEncoder().fit_transform(X['view_duration'])
X['productId_encoded'] = LabelEncoder().fit_transform(X['productId'])
# Out:
# /tmp/ipykernel_14832/2786766683.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['model_encoded'] = LabelEncoder().fit_transform(X['model'])
# /tmp/ipykernel_14832/2786766683.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['campaignId_encoded'] = LabelEncoder().fit_transform(X['campaignId'])
# /tmp/ipykernel_14832/2786766683.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
X
# Out:
#                  model campaignId  page_turn_count  view_duration  \
# 0             sm-g955f     000000               18        36000.0
# 1             sm-g955f     000000               40       161000.0
# 2             sm-g955f     000000               25        53000.0
# 3             sm-g955f     000000               25        27000.0
# 4             sm-g955f     000000                8       140000.0
# ...                ...        ...              ...            ...
# 208343  huawei+gra-l09     000000               43        90000.0
# 208344  huawei+gra-l09     000000                2        22000.0
# 208345  huawei+gra-l09     000000                1         8000.0
# 208346  huawei+gra-l09     000000                1        10000.0
# 208347  huawei+gra-l09     000000                3        40000.0
#
#                 productId  model_encoded  campaignId_encoded  \
# 0       com-bonial-kaufda            747                   0
# ...

# %%
#Split

X_encoded = X[['model_encoded','campaignId_encoded','page_turn_count_encoded','view_duration_encoded','productId_encoded']]

# %%
Y = df[['Churn']]

Y.head(5)
# Out:
#    Churn
# 0      0
# 1      0
# 2      0
# 3      0
# 4      1

# %% [markdown]
# # split data into train and test sets

# %%
seed = 7

test_size = 0.33

X_train, X_test, y_train, y_test = train_test_split(X_encoded, Y, test_size=test_size, random_state=seed)

# %%
print("train.shape : {}".format(X_train.shape))
print("test.shape : {}".format(X_test.shape))
# Out:
# train.shape : (139593, 5)
# test.shape : (68755, 5)

# %%
# %matplotlib inline
plt.figure(figsize=(13,8))

mask = np.triu(np.ones_like(X_train.corr(), dtype=bool))
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(X_train.corr(), mask=mask, cmap=cmap, annot=True)

plt.show()

# %%
X_train
# Out:
#         model_encoded  campaignId_encoded  page_turn_count_encoded  \
# 168558            744                   0                       38
# 74836              34                   0                        3
# 18907             345                  44                       40
# 35351             744                 378                        0
# 161838            746                   0                       11
# ...               ...                 ...                      ...
# 53459             742                 124                       14
# 10742             744                   0                        0
# 49689             310                   0                        0
# 189636            421                   0                        1
# 61615             860                 143                       32
#
#         view_duration_encoded  productId_encoded
# 168558                    787                  0
# 74836                      35                  0
# ...

# %%
X_train_corr = X_train.corr()

X_train_corr[(X_train_corr > 0.2) & (X_train_corr < 1.0)].stack()
# Out:
# page_turn_count_encoded  view_duration_encoded      0.449024
# view_duration_encoded    page_turn_count_encoded    0.449024
# dtype: float64

# %%
y_train
# Out:
#         Churn
# 168558      0
# 74836       1
# 18907       0
# 35351       1
# 161838      0
# ...       ...
# 53459       0
# 10742       1
# 49689       1
# 189636      1
# 61615       0
#
# [139593 rows x 1 columns]

# %%
# Pull data from y_train
plt.subplots(1,3,figsize=(16,5))
plt.subplot(131)
x = y_train['Churn'].value_counts()
colors = ["slateblue", "yellow"]
plt.pie(x.values, startangle=122, labels=[0,1], wedgeprops={"edgecolor":"white", "width":0.4}, radius=1.1, colors=colors, autopct="%1.1f%%", pctdistance=0.8)
plt.title('Percentage of Churn')
plt.subplot(132)
sns.countplot(y_train['Churn'], palette="cool", linewidth=2.0, edgecolor="navy")
plt.ylabel('')
plt.title('Distribution of Churn')
plt.subplot(133)

# # Pull data from X_train
# sns.countplot(X_train['view_duration_encoded'], palette="cool", linewidth=2.0, edgecolor="navy")
# plt.xticks(rotation=90)
# plt.xlabel('')
# plt.ylabel('')
# plt.title('Distribution of View Duration')
# plt.show()
# Out:
# /Users/am/jobs_env/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %% [markdown]
# # Lets do ML

# %% [markdown]
# ## XG_boost Classifier

# %%
# fit model no training data
model = XGBClassifier()
model.fit(X_train, y_train)
# Out:
# /Users/am/jobs_env/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/am/jobs_env/lib/python3.9/site-packages/sklearn/preprocessing/_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/am/jobs_env/lib/python3.9/site-packages/sklearn/preprocessing/_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# ...

# %%
# make predictions for test data
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([0, 1, 0, ..., 0, 0, 1])

# %% [markdown]
# # Evaluate Predictions for XG_boost

# %%
# evaluate predictions
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 100.00%

# %% [markdown]
# ## lets print the classification Report

# %%
#prediction and Classification Report
from sklearn.metrics import classification_report

print('Classification Report for {0}:'.format("model_xgboost"))
print (classification_report(y_test, y_pred))
# Out:
# Classification Report for model_xgboost:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     31947
#            1       1.00      1.00      1.00     36808
#
#     accuracy                           1.00     68755
#    macro avg       1.00      1.00      1.00     68755
# weighted avg       1.00      1.00      1.00     68755

# %%
import sklearn.metrics as metrics
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# Creates a confusion matrix
cm = metrics.confusion_matrix(y_test, y_pred) 

fig=plt.figure()
fig.add_subplot(111)
sns.heatmap(cm,annot=True,square=True,cbar=False,fmt="d", cmap=plt.cm.Blues)
plt.title('Xgboost model \nAccuracy:{0:.3f} \nMisClassification Error:{1:.3f}'.format(accuracy_score(y_test, y_pred),(1 - metrics.accuracy_score(y_test, y_pred))))
plt.xlabel("predicted label")
plt.ylabel("true label")
# Out:
# Text(91.68, 0.5, 'true label')

# %% [markdown]
# ## ROC

# %%
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_pred)

plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate, true_positive_rate)
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.1,1.2])
plt.ylim([-0.1,1.2])
plt.ylabel('True Positive Rate(Sensitivity)')
plt.xlabel('False Positive Rate(1-Specificity)')
plt.show()

# %% [markdown]
# ## AUC

# %%
# Area Under Curve
print(metrics.roc_auc_score(y_test, y_pred))
# Out:
# 1.0

# %% [markdown]
# # Time for some Random Forest

# %%
#RandomForest on the dataset
from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier()

rfc_model = rfc.fit(X_train, y_train)

pred_rf = rfc_model.predict(X_test)

print("Accuracy for Random Forest Model: %.2f" % (accuracy_score(y_test, pred_rf) * 100))
# Out:
# /tmp/ipykernel_14832/1644061335.py:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rfc_model = rfc.fit(X_train, y_train)
# Accuracy for Random Forest Model: 100.00

# %%
import sklearn.metrics as metrics
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# Creates a confusion matrix
cm = metrics.confusion_matrix(y_test, pred_rf) 

fig=plt.figure()
fig.add_subplot(111)
sns.heatmap(cm,annot=True,square=True,cbar=False,fmt="d")
plt.title('RandForest model \nAccuracy:{0:.3f} \nMisClassification Error:{1:.3f}'.format(accuracy_score(y_test, pred_rf),(1 - metrics.accuracy_score(y_test, pred_rf))))
plt.xlabel("predicted label")
plt.ylabel("true label")
# Out:
# Text(91.68, 0.5, 'true label')

# %% [markdown]
# # Lets use Cross-validation

# %%
# prepare models

models = []
models.append(('Xgboost', model))
models.append(('Random_forest', rfc_model))
# evaluate each model in turn
results = []
names = []
scoring = 'accuracy'
for name, model in models:
    kfold = model_selection.KFold(n_splits=10)
    cv_results = model_selection.cross_val_score(model, X_encoded, Y, cv=kfold, scoring=scoring)
    results.append(cv_results)
    names.append(name)
    msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)
# boxplot algorithm comparison
fig = plt.figure()
fig.suptitle('Algorithm Comparison')
ax = fig.add_subplot(111)
plt.boxplot(results)
ax.set_xticklabels(names)
plt.show()
# Out:
# /Users/am/jobs_env/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/am/jobs_env/lib/python3.9/site-packages/sklearn/preprocessing/_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/am/jobs_env/lib/python3.9/site-packages/sklearn/preprocessing/_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# ...

# %%
# Neural Network

# %%
X_train.shape
# Out:
# (139593, 5)

# %%
y_train_cat = np_utils.to_categorical(y_train.values)
y_train_cat.shape
# Out:
# (139593, 2)

# %%
input_dim = X_train.shape[1]
nb_classes = y_train_cat.shape[1]


model = Sequential()
model.add(Dense(128, input_dim=input_dim))
model.add(Activation('relu'))
model.add(Dropout(0.15))
model.add(Dense(128))
model.add(Activation('relu'))
model.add(Dropout(0.15))
model.add(Dense(nb_classes))
model.add(Activation('softmax'))
# Out:
# 2022-04-14 12:49:25.179355: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

print("Training...")
model.fit(X_train, y_train_cat, epochs=10, batch_size=16, validation_split=0.33, verbose=2)
# Out:
# Training...
# Epoch 1/10
# 5846/5846 - 6s - loss: 1.1823 - accuracy: 0.8539 - val_loss: 0.0963 - val_accuracy: 0.9579 - 6s/epoch - 1ms/step
# Epoch 2/10
# 5846/5846 - 5s - loss: 0.1496 - accuracy: 0.9481 - val_loss: 0.0864 - val_accuracy: 0.9859 - 5s/epoch - 902us/step
# Epoch 3/10
# 5846/5846 - 5s - loss: 0.1230 - accuracy: 0.9605 - val_loss: 0.1305 - val_accuracy: 0.9524 - 5s/epoch - 912us/step
# Epoch 4/10
# 5846/5846 - 5s - loss: 0.1160 - accuracy: 0.9638 - val_loss: 0.0818 - val_accuracy: 0.9700 - 5s/epoch - 905us/step
# Epoch 5/10
# 5846/5846 - 5s - loss: 0.1100 - accuracy: 0.9657 - val_loss: 0.0487 - val_accuracy: 0.9829 - 5s/epoch - 909us/step
# Epoch 6/10
# 5846/5846 - 5s - loss: 0.1045 - accuracy: 0.9678 - val_loss: 0.0671 - val_accuracy: 0.9715 - 5s/epoch - 915us/step
# Epoch 7/10
# 5846/5846 - 5s - loss: 0.1001 - accuracy: 0.9695 - val_loss: 0.0823 - val_accuracy: 0.9682 - 5s/epoch - 921us/step
# Epoch 8/10
# ...

# %%
print("Generating test predictions...")

predict_x=model.predict(X_test) 
pred_keras=np.argmax(predict_x,axis=1)
# Out:
# Generating test predictions...

# %%
import sklearn.metrics as metrics
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# Creates a confusion matrix
cm = metrics.confusion_matrix(y_test, pred_keras) 

fig=plt.figure()
fig.add_subplot(111)
sns.heatmap(cm,annot=True,square=True,cbar=False,fmt="d")
plt.title('MLP model \nAccuracy:{0:.3f} \nMisClassification Error:{1:.3f}'.format(accuracy_score(y_test, pred_keras),(1 - metrics.accuracy_score(y_test, pred_keras))))
plt.xlabel("predicted label")
plt.ylabel("true label")
# Out:
# Text(91.68, 0.5, 'true label')

# %% [markdown]
# # Saving the model

# %%
model.save('Churn_model.h5')

# %% [markdown]
# **** Answers to the questions *********
#
# How would you approach that problem?
# -> Churn: can be approached as a classification problem, where we can build a classifier to determine the probability of whether a customer will leave or not based on some features/indicators <br>
#
# What other data points would increase the accuracy of the algorithm?
# -> Other relevant features in general can be something like : [gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure', 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity] <br>
#
# Which features did you select and why ?
# -> the features i selected are visible in the notebook, as for why we can disscuss further when we meet. Generally speaking if the view duration is low and the page turn is low then most probably this customer is not using the app and is not likely to use it...
